# %% [markdown]
# # গ্রাম গরুর মাংসের জন্য উপকরণের তালিকা

# %%
def calculate_beef_recipe(beef_grams):
    # বেস মেজারমেন্ট (আপনার দেওয়া ১০১৪ গ্রামের জন্য)
    base_beef = 1014.0

    # অনুপাত অনুযায়ী উপকরণের ডিকশনারি (গ্রাম এককে)
    ingredients_ratio = {
        "Sliced Onion (পেঁয়াজ)": 214.0,
        "Sunflower Oil (তেল)": 130.0,
        "Ginger Paste (আদা)": 19.0,
        "Garlic Paste (রসুন)": 20.0,
        "Turmeric Powder (হলুদ)": 1.75,
        "Chilli Powder (মরিচ)": 3.38,
        "Cumin Powder (জিরা)": 4.17,
        "Coriander Powder (ধনিয়া)": 1.30,
        "Mixed Hot Spices (গরম মসলা)": 5.0,
        "Salt (লবণ)": 15.58
    }

    # ক্যালকুলেশন ফ্যাক্টর
    factor = beef_grams / base_beef

    print(f"--- {beef_grams} গ্রাম গরুর মাংসের জন্য উপকরণের তালিকা ---")
    results = {}

    for item, base_amount in ingredients_ratio.items():
        calculated_amount = round(base_amount * factor, 2)
        results[item] = calculated_amount
        print(f"{item}: {calculated_amount} গ্রাম")

    return None

# উদাহরণ: আপনি যদি ৫০০ গ্রাম মাংস রান্না করতে চান
calculate_beef_recipe(1000)
# Out:
# --- 1000 গ্রাম গরুর মাংসের জন্য উপকরণের তালিকা ---
# Sliced Onion (পেঁয়াজ): 211.05 গ্রাম
# Sunflower Oil (তেল): 128.21 গ্রাম
# Ginger Paste (আদা): 18.74 গ্রাম
# Garlic Paste (রসুন): 19.72 গ্রাম
# Turmeric Powder (হলুদ): 1.73 গ্রাম
# Chilli Powder (মরিচ): 3.33 গ্রাম
# Cumin Powder (জিরা): 4.11 গ্রাম
# Coriander Powder (ধনিয়া): 1.28 গ্রাম
# Mixed Hot Spices (গরম মসলা): 4.93 গ্রাম
# Salt (লবণ): 15.36 গ্রাম

# %%
def calculate_beef_recipe(beef_grams):
    # বেস মেজারমেন্ট (আপনার দেওয়া ১০০০ গ্রামের জন্য)
    base_beef = 1000.0

    # অনুপাত অনুযায়ী উপকরণের ডিকশনারি (গ্রাম এককে)
    ingredients_ratio = {
        "Sliced Onion (পেঁয়াজ)": 211.05,
        "Sunflower Oil (তেল)": 128.21,
        "Ginger Paste (আদা)": 18.74,
        "Garlic Paste (রসুন)": 19.72,
        "Turmeric Powder (হলুদ)": 1.73,
        "Chilli Powder (মরিচ)": 3.33,
        "Cumin Powder (জিরা)": 4.11,
        "Coriander Powder (ধনিয়া)": 1.28,
        "Mixed Hot Spices (গরম মসলা)": 4.93,
        "Salt (লবণ)": 15.36
    }

    # ক্যালকুলেশন ফ্যাক্টর
    factor = beef_grams / base_beef

    print(f"--- {beef_grams} গ্রাম গরুর মাংসের জন্য উপকরণের তালিকা ---")
    results = {}

    for item, base_amount in ingredients_ratio.items():
        calculated_amount = round(base_amount * factor, 2)
        results[item] = calculated_amount
        print(f"{item}: {calculated_amount} গ্রাম")

    return None



# উদাহরণ: আপনি যদি ৫০০ গ্রাম মাংস রান্না করতে চান

beefQuantity = float(input("Enter the quantity of beef (in grams): "))
calculate_beef_recipe(beefQuantity)
# Out:
# --- 35000.0 গ্রাম গরুর মাংসের জন্য উপকরণের তালিকা ---
# Sliced Onion (পেঁয়াজ): 7386.75 গ্রাম
# Sunflower Oil (তেল): 4487.35 গ্রাম
# Ginger Paste (আদা): 655.9 গ্রাম
# Garlic Paste (রসুন): 690.2 গ্রাম
# Turmeric Powder (হলুদ): 60.55 গ্রাম
# Chilli Powder (মরিচ): 116.55 গ্রাম
# Cumin Powder (জিরা): 143.85 গ্রাম
# Coriander Powder (ধনিয়া): 44.8 গ্রাম
# Mixed Hot Spices (গরম মসলা): 172.55 গ্রাম
# Salt (লবণ): 537.6 গ্রাম

# %% [markdown]
# ---
